# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import pandas_profiling
# !pip install pandas-profiling==3.1.0
# Out:
# Requirement already satisfied: pandas-profiling==3.1.0 in c:\users\patricia.sousa\anaconda4\lib\site-packages (3.1.0)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (0.12.1)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (0.1.12)
# Requirement already satisfied: markupsafe~=2.0.1 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (2.0.1)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (6.0)
# Requirement already satisfied: tangled-up-in-unicode==0.1.0 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (0.1.0)
# Requirement already satisfied: requests>=2.24.0 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (2.27.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (2.11.3)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (4.64.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (1.7.3)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (1.10.2)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (0.7.4)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (1.21.5)
# Requirement already satisfied: multimethod>=1.4 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (1.9)
# Requirement already satisfied: joblib~=1.0.1 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (1.0.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (1.4.2)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (3.5.1)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (0.5.1)
# Requirement already satisfied: phik>=0.11.1 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas-profiling==3.1.0) (0.12.2)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling==3.1.0) (21.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling==3.1.0) (2.7.1)
# Requirement already satisfied: Pillow in c:\users\patricia.sousa\anaconda4\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling==3.1.0) (9.0.1)
# Requirement already satisfied: imagehash in c:\users\patricia.sousa\anaconda4\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling==3.1.0) (4.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling==3.1.0) (2021.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from pydantic>=1.8.1->pandas-profiling==3.1.0) (4.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling==3.1.0) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from requests>=2.24.0->pandas-profiling==3.1.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from requests>=2.24.0->pandas-profiling==3.1.0) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from requests>=2.24.0->pandas-profiling==3.1.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\patricia.sousa\anaconda4\lib\site-packages (from requests>=2.24.0->pandas-profiling==3.1.0) (1.26.9)
# Requirement already satisfied: colorama in c:\users\patricia.sousa\anaconda4\lib\site-packages (from tqdm>=4.48.2->pandas-profiling==3.1.0) (0.4.4)
# Requirement already satisfied: PyWavelets in c:\users\patricia.sousa\anaconda4\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling==3.1.0) (1.3.0)

# %% [markdown]
# ### Análise com Pandas

# %%
df =pd.read_csv('fraud_dataset_example.csv') #carregamento do dataset
df
# Out:
#         step      type      amount     nameOrig  oldbalanceOrg  \
# 0          1   PAYMENT     9839.64  C1231006815      170136.00
# 1          1   PAYMENT     1864.28  C1666544295       21249.00
# 2          1  TRANSFER      181.00  C1305486145         181.00
# 3          1  CASH_OUT      181.00   C840083671         181.00
# 4          1   PAYMENT    11668.14  C2048537720       41554.00
# ...      ...       ...         ...          ...            ...
# 101608    10   PAYMENT     7477.02   C513257306         785.00
# 101609    10  CASH_OUT   282252.35   C210473293      220339.29
# 101610    10   PAYMENT    17289.01   C807582280           0.00
# 101611    10  TRANSFER  1347146.45  C1315779140        1605.00
# 101612    10  CASH_OUT   469539.21   C515691325       31133.00
#
#         newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0            160296.36  M1979787155            0.00            0.00        0
# 1             19384.72  M2044282225            0.00            0.00        0
# 2                 0.00   C553264065            0.00            0.00        1
# 3                 0.00    C38997010        21182.00            0.00        1
# 4             29885.86  M1230701703            0.00            0.00        0
# ...                ...          ...             ...             ...      ...
# 101608            0.00   M524833426            0.00            0.00        0
# 101609            0.00  C1172042998        95156.01        91286.97        0
# 101610            0.00   M334249577            0.00            0.00        0
# 101611            0.00  C1631408038       541639.43      2186953.43        0
# 101612            0.00  C1383702768            0.00       469539.21        0
#
#         isFlaggedFraud
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 101608               0
# 101609               0
# 101610               0
# 101611               0
# 101612               0
#
# [101613 rows x 11 columns]

# %%
df=df[['isFraud',                                  #Manipulei a coluna de fraudes para frente (melhor visualização)
       'isFlaggedFraud','step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
       'nameDest', 'oldbalanceDest', 'newbalanceDest']]

# %%
df
# Out:
#         isFraud  isFlaggedFraud  step      type      amount     nameOrig  \
# 0             0               0     1   PAYMENT     9839.64  C1231006815
# 1             0               0     1   PAYMENT     1864.28  C1666544295
# 2             1               0     1  TRANSFER      181.00  C1305486145
# 3             1               0     1  CASH_OUT      181.00   C840083671
# 4             0               0     1   PAYMENT    11668.14  C2048537720
# ...         ...             ...   ...       ...         ...          ...
# 101608        0               0    10   PAYMENT     7477.02   C513257306
# 101609        0               0    10  CASH_OUT   282252.35   C210473293
# 101610        0               0    10   PAYMENT    17289.01   C807582280
# 101611        0               0    10  TRANSFER  1347146.45  C1315779140
# 101612        0               0    10  CASH_OUT   469539.21   C515691325
#
#         oldbalanceOrg  newbalanceOrig     nameDest  oldbalanceDest  \
# 0           170136.00       160296.36  M1979787155            0.00
# 1            21249.00        19384.72  M2044282225            0.00
# 2              181.00            0.00   C553264065            0.00
# 3              181.00            0.00    C38997010        21182.00
# 4            41554.00        29885.86  M1230701703            0.00
# ...               ...             ...          ...             ...
# 101608         785.00            0.00   M524833426            0.00
# 101609      220339.29            0.00  C1172042998        95156.01
# 101610           0.00            0.00   M334249577            0.00
# 101611        1605.00            0.00  C1631408038       541639.43
# 101612       31133.00            0.00  C1383702768            0.00
#
#         newbalanceDest
# 0                 0.00
# 1                 0.00
# 2                 0.00
# 3                 0.00
# 4                 0.00
# ...                ...
# 101608            0.00
# 101609        91286.97
# 101610            0.00
# 101611      2186953.43
# 101612       469539.21
#
# [101613 rows x 11 columns]

# %%
colunas = {                     #renomeando as colunas para portugues
    'isFraud': 'fraude',
    'isFlaggedFraud':'super_fraude',
    'step':'tempo',
    'type':'tipo',
    'amount':'valor',
    'nameOrig':'cliente1',
    'oldbalanceOrg':'saldo_inicial_c1',
    'newbalanceOrig':'novo_saldo_c1',
    'nameDest':'cliente2',
    'oldbalanceDest':'saldo_inicial_c2',
    'newbalanceDest':'novo_saldo_c2',
}

# %%
df= df.rename(columns=colunas)
df
# Out:
#         fraude  super_fraude  tempo      tipo       valor     cliente1  \
# 0            0             0      1   PAYMENT     9839.64  C1231006815
# 1            0             0      1   PAYMENT     1864.28  C1666544295
# 2            1             0      1  TRANSFER      181.00  C1305486145
# 3            1             0      1  CASH_OUT      181.00   C840083671
# 4            0             0      1   PAYMENT    11668.14  C2048537720
# ...        ...           ...    ...       ...         ...          ...
# 101608       0             0     10   PAYMENT     7477.02   C513257306
# 101609       0             0     10  CASH_OUT   282252.35   C210473293
# 101610       0             0     10   PAYMENT    17289.01   C807582280
# 101611       0             0     10  TRANSFER  1347146.45  C1315779140
# 101612       0             0     10  CASH_OUT   469539.21   C515691325
#
#         saldo_inicial_c1  novo_saldo_c1     cliente2  saldo_inicial_c2  \
# 0              170136.00      160296.36  M1979787155              0.00
# 1               21249.00       19384.72  M2044282225              0.00
# 2                 181.00           0.00   C553264065              0.00
# 3                 181.00           0.00    C38997010          21182.00
# 4               41554.00       29885.86  M1230701703              0.00
# ...                  ...            ...          ...               ...
# 101608            785.00           0.00   M524833426              0.00
# 101609         220339.29           0.00  C1172042998          95156.01
# 101610              0.00           0.00   M334249577              0.00
# 101611           1605.00           0.00  C1631408038         541639.43
# 101612          31133.00           0.00  C1383702768              0.00
#
#         novo_saldo_c2
# 0                0.00
# 1                0.00
# 2                0.00
# 3                0.00
# 4                0.00
# ...               ...
# 101608           0.00
# 101609       91286.97
# 101610           0.00
# 101611     2186953.43
# 101612      469539.21
#
# [101613 rows x 11 columns]

# %% [markdown]
# ## Outras Informações

# %%
#Sem dados null e sem disparidade

df.describe()
# Out:
#               fraude  super_fraude          tempo         valor  \
# count  101613.000000      101613.0  101613.000000  1.016130e+05
# mean        0.001142           0.0       8.523457  1.740901e+05
# std         0.033768           0.0       1.820681  3.450199e+05
# min         0.000000           0.0       1.000000  3.200000e-01
# 25%         0.000000           0.0       8.000000  1.001659e+04
# 50%         0.000000           0.0       9.000000  5.338541e+04
# 75%         0.000000           0.0      10.000000  2.124984e+05
# max         1.000000           0.0      10.000000  1.000000e+07
#
#        saldo_inicial_c1  novo_saldo_c1  saldo_inicial_c2  novo_saldo_c2
# count      1.016130e+05   1.016130e+05      1.016130e+05   1.016130e+05
# mean       9.071753e+05   9.234992e+05      8.810428e+05   1.183998e+06
# std        2.829575e+06   2.867319e+06      2.399949e+06   2.797761e+06
# min        0.000000e+00   0.000000e+00      0.000000e+00   0.000000e+00
# 25%        0.000000e+00   0.000000e+00      0.000000e+00   0.000000e+00
# 50%        2.019047e+04   0.000000e+00      2.105800e+04   5.178343e+04
# 75%        1.947150e+05   2.192178e+05      5.919217e+05   1.063122e+06
# max        3.893942e+07   3.894623e+07      3.400874e+07   3.894623e+07

# %%
df.groupby('fraude').tempo.count() #Numero de fraudes totalizando (101497)
# Out:
# fraude
# 0    101497
# 1       116
# Name: tempo, dtype: int64

# %% [markdown]
# ## Aplicando Enconding no dataset

# %%
df = pd.get_dummies(data=df, columns=['tipo']) #usei o One-Hot-Encoding
df.head()
# Out:
#    fraude  super_fraude  tempo     valor     cliente1  saldo_inicial_c1  \
# 0       0             0      1   9839.64  C1231006815          170136.0
# 1       0             0      1   1864.28  C1666544295           21249.0
# 2       1             0      1    181.00  C1305486145             181.0
# 3       1             0      1    181.00   C840083671             181.0
# 4       0             0      1  11668.14  C2048537720           41554.0
#
#    novo_saldo_c1     cliente2  saldo_inicial_c2  novo_saldo_c2  tipo_CASH_IN  \
# 0      160296.36  M1979787155               0.0            0.0             0
# 1       19384.72  M2044282225               0.0            0.0             0
# 2           0.00   C553264065               0.0            0.0             0
# 3           0.00    C38997010           21182.0            0.0             0
# 4       29885.86  M1230701703               0.0            0.0             0
#
#    tipo_CASH_OUT  tipo_DEBIT  tipo_PAYMENT  tipo_TRANSFER
# 0              0           0             1              0
# 1              0           0             1              0
# 2              0           0             0              1
# 3              1           0             0              0
# 4              0           0             1              0

# %%
df= df.drop(['cliente1','cliente2','super_fraude'],axis = 1) #exclui algumas variaveis que eu não preciso usar

# %%
df
# Out:
#         fraude  tempo       valor  saldo_inicial_c1  novo_saldo_c1  \
# 0            0      1     9839.64         170136.00      160296.36
# 1            0      1     1864.28          21249.00       19384.72
# 2            1      1      181.00            181.00           0.00
# 3            1      1      181.00            181.00           0.00
# 4            0      1    11668.14          41554.00       29885.86
# ...        ...    ...         ...               ...            ...
# 101608       0     10     7477.02            785.00           0.00
# 101609       0     10   282252.35         220339.29           0.00
# 101610       0     10    17289.01              0.00           0.00
# 101611       0     10  1347146.45           1605.00           0.00
# 101612       0     10   469539.21          31133.00           0.00
#
#         saldo_inicial_c2  novo_saldo_c2  tipo_CASH_IN  tipo_CASH_OUT  \
# 0                   0.00           0.00             0              0
# 1                   0.00           0.00             0              0
# 2                   0.00           0.00             0              0
# 3               21182.00           0.00             0              1
# 4                   0.00           0.00             0              0
# ...                  ...            ...           ...            ...
# 101608              0.00           0.00             0              0
# 101609          95156.01       91286.97             0              1
# 101610              0.00           0.00             0              0
# 101611         541639.43     2186953.43             0              0
# 101612              0.00      469539.21             0              1
#
#         tipo_DEBIT  tipo_PAYMENT  tipo_TRANSFER
# 0                0             1              0
# 1                0             1              0
# 2                0             0              1
# 3                0             0              0
# 4                0             1              0
# ...            ...           ...            ...
# 101608           0             1              0
# 101609           0             0              0
# 101610           0             1              0
# 101611           0             0              1
# 101612           0             0              0
#
# [101613 rows x 12 columns]

# %% [markdown]
# ## Regressão logistica

# %% [markdown]
# nesse momento eu quero entender quanto meu modelo pode acertar se existe fraude ou não no pipeline

# %%
x = df.drop('fraude', axis=1)    #faço um drop da coluna fraude para considerar apenas ela como teste e treino
y = df['fraude']

# %%
from sklearn.model_selection import train_test_split ## defino o SEED e incluir os dados para rodar e separar no sklearn os dados teste 25% e treini 75%

SEED = 42

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state = SEED)

# %%
from sklearn.linear_model import LogisticRegression  #aqui apesar da acuracia esta aumenta minhas outras metricas esão muito 
from sklearn import metrics

lr = LogisticRegression(max_iter=1000, random_state=SEED)
lr.fit(x_train,y_train)
y_pred =lr.predict(x_test)


print("Acurácia:",metrics.accuracy_score(y_test, y_pred))
print("Precisão:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred)) 
print("F1:",metrics.f1_score(y_test, y_pred))
# Out:
# Acurácia: 0.9989765391276965
# Precisão: 0.2
# Recall: 0.043478260869565216
# F1: 0.07142857142857142

# %%
import matplotlib.pyplot as plt                      #construção da matriz de confusao para entender porque apesar da acuaracia estar alta a precisao esta baixa
from sklearn.metrics import Confusion_matrix
from sklearn.datasets import make_classification
from sklearn.metrics import ConfusionMatrixDisplay
# %matplotlib inline


cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [66], in <cell line: 2>()
#       1 import matplotlib.pyplot as plt                      #construção da matriz de confusao para entender porque apesar da acuaracia estar alta a precisao esta baixa
# ----> 2 from sklearn.metrics import Confusion_matrix
#       3 from sklearn.datasets import make_classification
#       4 from sklearn.metrics import ConfusionMatrixDisplay
#
# ImportError: cannot import name 'Confusion_matrix' from 'sklearn.metrics' (C:\Users\patricia.sousa\Anaconda4\lib\site-packages\sklearn\metrics\__init__.py)

# %%
y_pred_proba = lr.predict_proba(x_test)[::, 1]
fpr, tpr, _= metrics.roc_curve(y_test, y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)

plt.rcParams['figure.figsize'] = (12., 8.)
plt.plot(fpr,tpr,label="LR, auc="+str(auc))
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
